# %%
import sys
import os
import pandas as pd
from src.board import create_board
from src.moves import parse_notation, move_piece

# %%
board = create_board()

# %%
board
# Out:
#     A   B   C   D   E   F   G   H
# 8  bR  bN  bB  bQ  bK  bB  bN  bR
# 7  bP  bP  bP  bP  bP  bP  bP  bP
# 6   .   .   .   .   .   .   .   .
# 5   .   .   .   .   .   .   .   .
# 4   .   .   .   .   .   .   .   .
# 3   .   .   .   .   .   .   .   .
# 2  wP  wP  wP  wP  wP  wP  wP  wP
# 1  wR  wN  wB  wQ  wK  wB  wN  wR

# %%
print(parse_notation('e4'))
# Out:
# (4, 4)

# %%
board = move_piece(board, 'E2', 'E4')

# %%
board
# Out:
#     A   B   C   D   E   F   G   H
# 8  bR  bN  bB  bQ  bK  bB  bN  bR
# 7  bP  bP  bP  bP  bP  bP  bP  bP
# 6   .   .   .   .   .   .   .   .
# 5   .   .   .   .   .   .   .   .
# 4   .   .   .   .  wP   .   .   .
# 3   .   .   .   .   .   .   .   .
# 2  wP  wP  wP  wP   .  wP  wP  wP
# 1  wR  wN  wB  wQ  wK  wB  wN  wR
